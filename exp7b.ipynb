# %% [markdown]
# # Exp7b: Voting #

# %%
from glob import glob

import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.cross_validation import cross_val_score, cross_val_predict, StratifiedKFold
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import VotingClassifier
from sklearn.preprocessing import Normalizer

from glove_transformer import GloveVectorizer

data = pd.read_csv(open('semeval2016-task6-trainingdata-utf-8.txt'), '\t',
                   encoding='utf8',
                   index_col=0)

targets = list(data.Target.unique()) + ['All']

macro_f_scorer = make_scorer(fbeta_score,
                             beta=1.0,
                             labels=['AGAINST', 'FAVOR'],
                             average='macro')


glove_fnames = glob('glove_vecs/*.pkl')
glove_ids = [fname.split('/')[-1].split('_')[0] for fname in glove_fnames]

# %%
    
for fname, glove_id in zip(glove_fnames, glove_ids):
    print 80 * '-'
    print 'GLOVE VECTORS:', glove_id
    print 80 * '-'

    glove_vecs = pd.read_pickle(fname)

    glove_clf = Pipeline([('vect', GloveVectorizer(glove_vecs)),
                          ('clf', LinearSVC(C=0.1,
                                                     #solver='lbfgs',
                                                     #multi_class='multinomial',
                                                     class_weight='balanced',
                                                     ))])

    char_clf = Pipeline([('vect', CountVectorizer(decode_error='ignore',
                                                  lowercase=False,
                                                  min_df=5,
                                                  ngram_range=(3, 3),
                                                  analyzer='char')),
                         ('clf', MultinomialNB())])

    word_clf = Pipeline([('vect', CountVectorizer(decode_error='ignore',
                                                  lowercase=False,
                                                  ngram_range=(2, 2))),
                         ('clf', MultinomialNB())])

    vot_clf = VotingClassifier(estimators=[('char', char_clf),
                                           ('word', word_clf),
                                           ('glove', glove_clf)],
                               voting='hard',
                               weights=[1, 1, 2])
    
    for target in targets:
        print 80 * "="
        print target
        print 80 * "="

        target_data = data[data.Target == target] if target != 'All' else data
        true_stances = target_data.Stance
            
        cv = StratifiedKFold(true_stances, n_folds=5, shuffle=True, random_state=1)

        pred_stances = cross_val_predict(vot_clf, target_data.Tweet, true_stances, cv=cv)
        print classification_report(true_stances, pred_stances, digits=4)

        macro_f = fbeta_score(true_stances, pred_stances, 1.0,
                              labels=['AGAINST', 'FAVOR'], average='macro')
        print 'macro-average of F-score(FAVOR) and F-score(AGAINST): {:.4f}\n'.format(
                macro_f)
# Out:
# --------------------------------------------------------------------------------
# GLOVE VECTORS: glove.42B.300d
# --------------------------------------------------------------------------------
# ================================================================================
# Atheism
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7310    0.8849    0.8006       304
#       FAVOR     0.5325    0.4457    0.4852        92
#        NONE     0.6912    0.4017    0.5081       117
#
# avg / total     0.6863    0.6959    0.6773       513
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6429
#
# ================================================================================
# Climate Change is a Real Concern
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.3846    0.3333    0.3571        15
#       FAVOR     0.7034    0.8726    0.7789       212
#        NONE     0.7983    0.5655    0.6620       168
#
# avg / total     0.7317    0.7215    0.7132       395
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5680
#
# ================================================================================
# Feminist Movement
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6290    0.7805    0.6966       328
#       FAVOR     0.5026    0.4571    0.4788       210
#        NONE     0.5152    0.2698    0.3542       126
#
# avg / total     0.5674    0.5813    0.5627       664
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5877
#
# ================================================================================
# Hillary Clinton
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6538    0.7950    0.7175       361
#       FAVOR     0.3804    0.3125    0.3431       112
#        NONE     0.5926    0.3855    0.4672       166
#
# avg / total     0.5900    0.6041    0.5868       639
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5303
#
# ================================================================================
# Legalization of Abortion
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6820    0.8862    0.7708       334
#       FAVOR     0.5000    0.3429    0.4068       105
#        NONE     0.7320    0.4329    0.5441       164
#
# avg / total     0.6639    0.6683    0.6458       603
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5888
#
# ================================================================================
# All
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6508    0.7832    0.7109      1342
#       FAVOR     0.5528    0.4651    0.5052       731
#        NONE     0.5822    0.4588    0.5132       741
#
# avg / total     0.6073    0.6151    0.6054      2814
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6080
#
# --------------------------------------------------------------------------------
# GLOVE VECTORS: glove.6B.100d
# --------------------------------------------------------------------------------
# ================================================================================
# Atheism
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7408    0.8651    0.7982       304
#       FAVOR     0.5375    0.4674    0.5000        92
#        NONE     0.6795    0.4530    0.5436       117
#
# avg / total     0.6904    0.6998    0.6866       513
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6491
#
# ================================================================================
# Climate Change is a Real Concern
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.2632    0.3333    0.2941        15
#       FAVOR     0.6958    0.8632    0.7705       212
#        NONE     0.7788    0.5238    0.6263       168
#
# avg / total     0.7147    0.6987    0.6911       395
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5323
#
# ================================================================================
# Feminist Movement
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6199    0.7409    0.6750       328
#       FAVOR     0.5196    0.4429    0.4781       210
#        NONE     0.4624    0.3413    0.3927       126
#
# avg / total     0.5583    0.5708    0.5592       664
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5766
#
# ================================================================================
# Hillary Clinton
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6667    0.7867    0.7217       361
#       FAVOR     0.3978    0.3304    0.3610       112
#        NONE     0.4583    0.3313    0.3846       166
#
# avg / total     0.5654    0.5884    0.5709       639
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5414
#
# ================================================================================
# Legalization of Abortion
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6787    0.8473    0.7537       334
#       FAVOR     0.4353    0.3524    0.3895       105
#        NONE     0.6337    0.3902    0.4830       164
#
# avg / total     0.6240    0.6368    0.6166       603
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5716
#
# ================================================================================
# All
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6334    0.8048    0.7089      1342
#       FAVOR     0.5560    0.4008    0.4658       731
#        NONE     0.5636    0.4426    0.4958       741
#
# avg / total     0.5949    0.6045    0.5896      2814
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5874
#
# --------------------------------------------------------------------------------
# GLOVE VECTORS: glove.6B.200d
# --------------------------------------------------------------------------------
# ================================================================================
# Atheism
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7298    0.8618    0.7903       304
#       FAVOR     0.5500    0.4783    0.5116        92
#        NONE     0.6892    0.4359    0.5340       117
#
# avg / total     0.6883    0.6959    0.6819       513
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6510
#
# ================================================================================
# Climate Change is a Real Concern
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.5000    0.4000    0.4444        15
#       FAVOR     0.6960    0.8962    0.7835       212
#        NONE     0.8091    0.5298    0.6403       168
#
# avg / total     0.7366    0.7215    0.7097       395
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6140
#
# ================================================================================
# Feminist Movement
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.5877    0.7561    0.6613       328
#       FAVOR     0.5118    0.4143    0.4579       210
#        NONE     0.4861    0.2778    0.3535       126
#
# avg / total     0.5444    0.5572    0.5386       664
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5596
#
# ================================================================================
# Hillary Clinton
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6698    0.7978    0.7282       361
#       FAVOR     0.3269    0.3036    0.3148       112
#        NONE     0.5429    0.3434    0.4207       166
#
# avg / total     0.5767    0.5931    0.5758       639
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5215
#
# ================================================================================
# Legalization of Abortion
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6899    0.8593    0.7653       334
#       FAVOR     0.4535    0.3714    0.4084       105
#        NONE     0.6535    0.4024    0.4981       164
#
# avg / total     0.6388    0.6501    0.6305       603
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5869
#
# ================================================================================
# All
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6393    0.7936    0.7081      1342
#       FAVOR     0.5515    0.4172    0.4751       731
#        NONE     0.5849    0.4696    0.5210       741
#
# avg / total     0.6021    0.6105    0.5983      2814
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5916
#
# --------------------------------------------------------------------------------
# GLOVE VECTORS: glove.6B.300d
# --------------------------------------------------------------------------------
# ================================================================================
# Atheism
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7205    0.8651    0.7862       304
#       FAVOR     0.5000    0.4457    0.4713        92
#        NONE     0.7121    0.4017    0.5137       117
#
# avg / total     0.6791    0.6842    0.6676       513
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6288
#
# ================================================================================
# Climate Change is a Real Concern
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.4000    0.2667    0.3200        15
#       FAVOR     0.6859    0.8962    0.7771       212
#        NONE     0.7963    0.5119    0.6232       168
#
# avg / total     0.7220    0.7089    0.6943       395
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5485
#
# ================================================================================
# Feminist Movement
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.5962    0.7561    0.6667       328
#       FAVOR     0.5056    0.4286    0.4639       210
#        NONE     0.4571    0.2540    0.3265       126
#
# avg / total     0.5411    0.5572    0.5380       664
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5653
#
# ================================================================================
# Hillary Clinton
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6467    0.7756    0.7053       361
#       FAVOR     0.3505    0.3036    0.3254       112
#        NONE     0.5046    0.3313    0.4000       166
#
# avg / total     0.5578    0.5775    0.5594       639
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5153
#
# ================================================================================
# Legalization of Abortion
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6799    0.8713    0.7638       334
#       FAVOR     0.5270    0.3714    0.4358       105
#        NONE     0.6733    0.4146    0.5132       164
#
# avg / total     0.6515    0.6600    0.6385       603
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5998
#
# ================================================================================
# All
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6391    0.7839    0.7041      1342
#       FAVOR     0.5281    0.4364    0.4779       731
#        NONE     0.5851    0.4453    0.5057       741
#
# avg / total     0.5961    0.6045    0.5931      2814
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5910
#
# --------------------------------------------------------------------------------
# GLOVE VECTORS: glove.6B.50d
# --------------------------------------------------------------------------------
# ================================================================================
# Atheism
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7443    0.8520    0.7945       304
#       FAVOR     0.5395    0.4457    0.4881        92
#        NONE     0.6517    0.4957    0.5631       117
#
# avg / total     0.6864    0.6979    0.6868       513
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6413
#
# ================================================================================
# Climate Change is a Real Concern
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.1842    0.4667    0.2642        15
#       FAVOR     0.7437    0.8349    0.7867       212
#        NONE     0.8151    0.5774    0.6760       168
#
# avg / total     0.7528    0.7114    0.7197       395
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5254
#
# ================================================================================
# Feminist Movement
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6102    0.7683    0.6802       328
#       FAVOR     0.5235    0.3714    0.4345       210
#        NONE     0.4314    0.3492    0.3860       126
#
# avg / total     0.5488    0.5633    0.5467       664
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5574
#
# ================================================================================
# Hillary Clinton
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6776    0.8033    0.7351       361
#       FAVOR     0.3913    0.3214    0.3529       112
#        NONE     0.4874    0.3494    0.4070       166
#
# avg / total     0.5780    0.6009    0.5829       639
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5440
#
# ================================================================================
# Legalization of Abortion
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6879    0.8713    0.7688       334
#       FAVOR     0.5946    0.4190    0.4916       105
#        NONE     0.6887    0.4451    0.5407       164
#
# avg / total     0.6719    0.6766    0.6585       603
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6302
#
# ================================================================================
# All
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6152    0.8159    0.7015      1342
#       FAVOR     0.5268    0.3625    0.4295       731
#        NONE     0.5650    0.4049    0.4717       741
#
# avg / total     0.5790    0.5899    0.5703      2814
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5655
#
# --------------------------------------------------------------------------------
# GLOVE VECTORS: glove.840B.300d
# --------------------------------------------------------------------------------
# ================================================================================
# Atheism
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7280    0.8980    0.8041       304
#       FAVOR     0.5571    0.4239    0.4815        92
#        NONE     0.6176    0.3590    0.4541       117
#
# avg / total     0.6722    0.6901    0.6664       513
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6428
#
# ================================================================================
# Climate Change is a Real Concern
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.5556    0.3333    0.4167        15
#       FAVOR     0.6838    0.8774    0.7686       212
#        NONE     0.7632    0.5179    0.6170       168
#
# avg / total     0.7127    0.7038    0.6908       395
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5926
#
# ================================================================================
# Feminist Movement
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6108    0.7561    0.6757       328
#       FAVOR     0.4972    0.4190    0.4548       210
#        NONE     0.4074    0.2619    0.3188       126
#
# avg / total     0.5363    0.5557    0.5381       664
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5653
#
# ================================================================================
# Hillary Clinton
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6473    0.8033    0.7169       361
#       FAVOR     0.4286    0.2946    0.3492       112
#        NONE     0.4386    0.3012    0.3571       166
#
# avg / total     0.5548    0.5837    0.5590       639
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5331
#
# ================================================================================
# Legalization of Abortion
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6667    0.8623    0.7520       334
#       FAVOR     0.5000    0.3619    0.4199       105
#        NONE     0.6632    0.3841    0.4865       164
#
# avg / total     0.6367    0.6451    0.6219       603
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5859
#
# ================================================================================
# All
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6281    0.7817    0.6965      1342
#       FAVOR     0.5593    0.4514    0.4996       731
#        NONE     0.5433    0.4062    0.4649       741
#
# avg / total     0.5879    0.5970    0.5844      2814
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5981
#
# --------------------------------------------------------------------------------
# GLOVE VECTORS: glove.twitter.27B.100d
# --------------------------------------------------------------------------------
# ================================================================================
# Atheism
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7521    0.8783    0.8103       304
#       FAVOR     0.5479    0.4348    0.4848        92
#        NONE     0.6588    0.4786    0.5545       117
#
# avg / total     0.6942    0.7076    0.6936       513
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6476
#
# ================================================================================
# Climate Change is a Real Concern
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.2353    0.2667    0.2500        15
#       FAVOR     0.7011    0.8962    0.7867       212
#        NONE     0.8598    0.5476    0.6691       168
#
# avg / total     0.7509    0.7241    0.7163       395
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5184
#
# ================================================================================
# Feminist Movement
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6160    0.7530    0.6776       328
#       FAVOR     0.5198    0.4381    0.4755       210
#        NONE     0.4651    0.3175    0.3774       126
#
# avg / total     0.5569    0.5708    0.5567       664
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5765
#
# ================================================================================
# Hillary Clinton
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6784    0.8006    0.7344       361
#       FAVOR     0.4685    0.4643    0.4664       112
#        NONE     0.5784    0.3554    0.4403       166
#
# avg / total     0.6156    0.6260    0.6110       639
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6004
#
# ================================================================================
# Legalization of Abortion
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7047    0.8503    0.7707       334
#       FAVOR     0.4632    0.4190    0.4400       105
#        NONE     0.7143    0.4573    0.5576       164
#
# avg / total     0.6653    0.6683    0.6552       603
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6053
#
# ================================================================================
# All
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6434    0.8040    0.7148      1342
#       FAVOR     0.5358    0.3995    0.4577       731
#        NONE     0.5591    0.4467    0.4966       741
#
# avg / total     0.5933    0.6048    0.5906      2814
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5862
#
# --------------------------------------------------------------------------------
# GLOVE VECTORS: glove.twitter.27B.200d
# --------------------------------------------------------------------------------
# ================================================================================
# Atheism
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7302    0.8816    0.7988       304
#       FAVOR     0.5211    0.4022    0.4540        92
#        NONE     0.6267    0.4017    0.4896       117
#
# avg / total     0.6691    0.6862    0.6664       513
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6264
#
# ================================================================================
# Climate Change is a Real Concern
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.3333    0.3333    0.3333        15
#       FAVOR     0.6894    0.8585    0.7647       212
#        NONE     0.7931    0.5476    0.6479       168
#
# avg / total     0.7200    0.7063    0.6986       395
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5490
#
# ================================================================================
# Feminist Movement
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6126    0.7713    0.6829       328
#       FAVOR     0.5000    0.4238    0.4588       210
#        NONE     0.5068    0.2937    0.3719       126
#
# avg / total     0.5569    0.5708    0.5530       664
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5708
#
# ================================================================================
# Hillary Clinton
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6722    0.7895    0.7261       361
#       FAVOR     0.4286    0.3482    0.3842       112
#        NONE     0.4677    0.3494    0.4000       166
#
# avg / total     0.5764    0.5978    0.5815       639
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5552
#
# ================================================================================
# Legalization of Abortion
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7050    0.8443    0.7684       334
#       FAVOR     0.5172    0.4286    0.4688       105
#        NONE     0.6810    0.4817    0.5643       164
#
# avg / total     0.6658    0.6733    0.6607       603
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6186
#
# ================================================================================
# All
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6422    0.8025    0.7135      1342
#       FAVOR     0.5422    0.4309    0.4802       731
#        NONE     0.5468    0.4103    0.4688       741
#
# avg / total     0.5911    0.6027    0.5884      2814
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5968
#
# --------------------------------------------------------------------------------
# GLOVE VECTORS: glove.twitter.27B.25d
# --------------------------------------------------------------------------------
# ================================================================================
# Atheism
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7395    0.8684    0.7988       304
#       FAVOR     0.4937    0.4239    0.4561        92
#        NONE     0.5974    0.3932    0.4742       117
#
# avg / total     0.6630    0.6803    0.6633       513
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6275
#
# ================================================================================
# Climate Change is a Real Concern
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.1714    0.4000    0.2400        15
#       FAVOR     0.6892    0.8160    0.7473       212
#        NONE     0.7706    0.5000    0.6065       168
#
# avg / total     0.7042    0.6658    0.6682       395
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.4937
#
# ================================================================================
# Feminist Movement
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6154    0.7805    0.6882       328
#       FAVOR     0.5208    0.3571    0.4237       210
#        NONE     0.4423    0.3651    0.4000       126
#
# avg / total     0.5526    0.5678    0.5499       664
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5560
#
# ================================================================================
# Hillary Clinton
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6682    0.8089    0.7318       361
#       FAVOR     0.4231    0.3929    0.4074       112
#        NONE     0.5306    0.3133    0.3939       166
#
# avg / total     0.5895    0.6072    0.5872       639
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5696
#
# ================================================================================
# Legalization of Abortion
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6690    0.8533    0.7500       334
#       FAVOR     0.3896    0.2857    0.3297       105
#        NONE     0.5800    0.3537    0.4394       164
#
# avg / total     0.5962    0.6186    0.5923       603
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5398
#
# ================================================================================
# All
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6014    0.8308    0.6977      1342
#       FAVOR     0.4742    0.3146    0.3783       731
#        NONE     0.5095    0.3266    0.3980       741
#
# avg / total     0.5442    0.5640    0.5358      2814
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5380
#
# --------------------------------------------------------------------------------
# GLOVE VECTORS: glove.twitter.27B.50d
# --------------------------------------------------------------------------------
# ================================================================================
# Atheism
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7430    0.8750    0.8036       304
#       FAVOR     0.5270    0.4239    0.4699        92
#        NONE     0.6790    0.4701    0.5556       117
#
# avg / total     0.6897    0.7018    0.6872       513
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6368
#
# ================================================================================
# Climate Change is a Real Concern
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.1220    0.3333    0.1786        15
#       FAVOR     0.6996    0.8019    0.7473       212
#        NONE     0.7928    0.5238    0.6308       168
#
# avg / total     0.7173    0.6658    0.6761       395
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.4629
#
# ================================================================================
# Feminist Movement
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6173    0.7622    0.6821       328
#       FAVOR     0.4968    0.3714    0.4251       210
#        NONE     0.4902    0.3968    0.4386       126
#
# avg / total     0.5551    0.5693    0.5546       664
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5536
#
# ================================================================================
# Hillary Clinton
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6856    0.8033    0.7398       361
#       FAVOR     0.4369    0.4018    0.4186       112
#        NONE     0.5044    0.3434    0.4086       166
#
# avg / total     0.5949    0.6135    0.5975       639
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5792
#
# ================================================================================
# Legalization of Abortion
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.7050    0.8443    0.7684       334
#       FAVOR     0.5000    0.4667    0.4828       105
#        NONE     0.6762    0.4329    0.5279       164
#
# avg / total     0.6615    0.6667    0.6532       603
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.6256
#
# ================================================================================
# All
# ================================================================================
#              precision    recall  f1-score   support
#
#     AGAINST     0.6348    0.8070    0.7106      1342
#       FAVOR     0.5134    0.3940    0.4458       731
#        NONE     0.5484    0.4049    0.4658       741
#
# avg / total     0.5805    0.5938    0.5774      2814
#
# macro-average of F-score(FAVOR) and F-score(AGAINST): 0.5782
